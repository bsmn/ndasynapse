# %%
import os
import json
import synapseclient
import pandas
import requests
import boto3
import nda_aws_token_generator
import logging

pandas.options.display.max_rows = None
pandas.options.display.max_columns = None
pandas.options.display.max_colwidth = 1000

logger = logging.getLogger("main")
logger.setLevel(logging.DEBUG)
#create console handler and set level to debug
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)

# NDA Configuration
REFERENCE_GUID = 'NDAR_INVRT663MBL'

# This is an old genomics subject
EXCLUDE_GENOMICS_SUBJECTS = ('92027', )
# EXCLUDE_EXPERIMENTS = ('534', '535')
EXCLUDE_EXPERIMENTS = ()

nda_bucket_name = 'nda-bsmn'

# Synapse configuration
synapse_data_folder = 'syn7872188'
synapse_data_folder_id = int(synapse_data_folder.replace('syn', ''))
storage_location_id = '9209'

def flattenjson( b, delim ):
    val = {}
    for i in b.keys():
        if isinstance( b[i], dict ):
            get = flattenjson( b[i], delim )
            for j in get.keys():
                val[ i + delim + j ] = get[j]
        else:
            val[i] = b[i]

    return val

# %%
s3 = boto3.resource("s3")
obj = s3.Object('kdaily-lambda-creds.sagebase.org', 'ndalogs_config.json')

config = json.loads(obj.get()['Body'].read())

ndaconfig = config['nda']

tokengenerator = nda_aws_token_generator.NDATokenGenerator()
mytoken = tokengenerator.generate_token(ndaconfig['username'],
                                        ndaconfig['password'])

session = boto3.Session(
    aws_access_key_id=mytoken.access_key,
    aws_secret_access_key=mytoken.secret_key,
    aws_session_token=mytoken.session
)

s3_nda = session.resource("s3")

# %%
r = requests.get("https://ndar.nih.gov/api/guid/{}/data?short_name=genomics_sample03".format(REFERENCE_GUID), 
                 auth=requests.auth.HTTPBasicAuth(ndaconfig['username'], 
                                                  ndaconfig['password']),
                 headers={'Accept': 'application/json'})

guid_data = json.loads(r.text)

tmp = [{col['name']: col['value'] for col in row['dataElement']} 
       for row in guid_data['age'][0]['dataStructureRow']]
    
samples = pandas.io.json.json_normalize(tmp)

# %%
experiment_ids = samples.EXPERIMENT_ID.unique().tolist()

# %%
df = pandas.DataFrame()

for experiment_id in experiment_ids:
    r = requests.get("https://ndar.nih.gov/api/experiment/{}".format(experiment_id), 
                     auth=requests.auth.HTTPBasicAuth(ndaconfig['username'], 
                                                      ndaconfig['password']),
                     headers={'Accept': 'application/json'})

    guid_data = json.loads(r.text)
    guid_data_flat = flattenjson(guid_data[u'omicsOrFMRIOrEEG']['sections'], '.')

    fix_keys = ['processing.processingKits.processingKit', 
               'additionalinformation.equipment.equipmentName',
               'extraction.extractionKits.extractionKit',
                'additionalinformation.analysisSoftware.software']

    for key in fix_keys:
        foo = guid_data_flat[key]
        tmp = ",".join(map(lambda x: "%s %s" % (x['vendorName'], x['value']), foo))
        guid_data_flat[key] = tmp

    foo = guid_data_flat['processing.processingProtocols.processingProtocol']
    tmp = ",".join(map(lambda x: "%s: %s" % (x['technologyName'], x['value']), foo))
    guid_data_flat['processing.processingProtocols.processingProtocol'] = tmp

    guid_data_flat['extraction.extractionProtocols.protocolName'] = ",".join(
        guid_data_flat['extraction.extractionProtocols.protocolName'])

    guid_data_flat['experiment_id'] = experiment_id
    
    df = df.append(guid_data_flat, ignore_index=True)

# %%
df
# Out:
#   additionalinformation.analysisSoftware.software  \
# 0                           Custom Custom scripts
# 1                               IrysView IrysView
# 2               Illumina Genome Analyzer Pipeline
# 3               Illumina Genome Analyzer Pipeline
# 4                                  Illumina Isaac
#
#   additionalinformation.equipment.equipmentName experiment_id  \
# 0                           Illumina HiSeq 4000           535
# 1                              BioNano IrysView           533
# 2            Illumina MiSeq,Illumina HiSeq 4000           641
# 3                           Illumina HiSeq 2500           643
# 4                          Illumina HiSeq X Ten           534
#
#   experimentparameters.molecule.moleculeName  \
# 0                                        DNA
# 1                                        DNA
# 2                                        DNA
# 3                                        DNA
# 4                                        DNA
#
#   experimentparameters.molecule.moleculeSubType  \
# 0                                          gDNA
# 1                                          gDNA
# 2                                          gDNA
# 3                                          gDNA
# 4                                          gDNA
#
#   experimentparameters.platform.platformName  \
# 0                        Illumina Sequencing
# 1                                       Irys
# 2                       SeqCap EZ Exome v2.0
# 3                        Illumina Sequencing
# 4                        Illumina Sequencing
#
#   experimentparameters.platform.platformSubType  \
# 0                           Illumina Sequencing
# 1                                          Irys
# 2                                           NGS
# 3                           Illumina Sequencing
# 4                           Illumina Sequencing
#
#   experimentparameters.platform.vendorName  \
# 0                                 Illumina
# 1                         BioNano Genomics
# 2                                Nimblegen
# 3                                 Illumina
# 4                                 Illumina
#
#   experimentparameters.technology.applicationName  \
# 0                      Next Generation Sequencing
# 1                    Whole genome optical imaging
# 2                      Next Generation Sequencing
# 3                      Next Generation Sequencing
# 4                      Next Generation Sequencing
#
#   experimentparameters.technology.applicationSubType  \
# 0                            Whole genome sequencing
# 1                             Optical genome imaging
# 2                                   Exome sequencing
# 3                                   Exome sequencing
# 4                            Whole genome sequencing
#
#   experimentparameters.technology.moleculeName  \
# 0                                          DNA
# 1                                          DNA
# 2                                          DNA
# 3                                          DNA
# 4                                          DNA
#
#   experimentparameters.technology.technologyName  \
# 0                                     sequencing
# 1                                 Genome imaging
# 2                                     sequencing
# 3                                     sequencing
# 4                                     sequencing
#
#   experimentparameters.technology.technologySubType  \
# 0                                        sequencing
# 1                                              None
# 2                                  Sequence capture
# 3                                        sequencing
# 4                                        sequencing
#
#                                                 extraction.extractionKits.extractionKit  \
# 0          Qiagen DNeasy Blood & Tissue Kit,Qiagen Qiagen REPLI-g Single Cell Kit (MDA)
# 1  Custom Proteinase K digestion followed by NaCl salting-out and chloroform extraction
# 2                                                         Not Applicable Not Applicable
# 3                                                             Qiagen Gentra Puregen kit
# 4                                                      Qiagen DNeasy Blood & Tissue Kit
#
#   extraction.extractionKits.moleculeName  \
# 0                                    DNA
# 1                                    DNA
# 2                                    DNA
# 3                                    DNA
# 4                                    DNA
#
#   extraction.extractionProtocols.moleculeName  \
# 0                                         DNA
# 1                                         DNA
# 2                                         DNA
# 3                                         DNA
# 4                                         DNA
#
#   extraction.extractionProtocols.protocolName  \
# 0                    Genomic DNA purification
# 1                    Genomic DNA purification
# 2                    Genomic DNA purification
# 3                    Genomic DNA purification
# 4                    Genomic DNA purification
#
#   processing.processingKits.moleculeName  \
# 0                                    DNA
# 1                                    DNA
# 2                                    DNA
# 3                                    DNA
# 4                                    DNA
#
#                      processing.processingKits.processingKit  \
# 0                        Illumina TruSeq DNA PCR-Free 350 bp
# 1                           Custom processing kit Processing
# 2                    Illumina Paired-End DNA Sample Prep Kit
# 3  Agilent Technologies SureSelectXT2 Human All Exon V4+UTRs
# 4                        Illumina TruSeq DNA PCR-Free 350 bp
#
#   processing.processingProtocols.moleculeName  \
# 0                                         DNA
# 1                                         DNA
# 2                                         DNA
# 3                                         DNA
# 4                                         DNA
#
#                                       processing.processingProtocols.processingProtocol
# 0  sequencing: sequencing,sequencing: workflow analysis,sequencing: library preparation
# 1                                          Genome imaging: DNA isolation and processing
# 2                                                                sequencing: sequencing
# 3                                                             sequencing: Exome Capture
# 4  sequencing: sequencing,sequencing: workflow analysis,sequencing: library preparation
