# %%
import os
import json
import synapseclient
import StringIO
import csv
import boto
import pandas
import json

def alias_column(df, column_name, alias_dict):
    """Alias a column of a Pandas DataFrame.
    
    At a minimum, copies a column to the aliased column name.
    
    If 'column_aliases' are specified for the column, then values in the new column are replaced.
    
    """
       
    alias = alias_dict['alias']
    
    try:
        column_from = alias_dict['column_aliases'].keys()
        column_to = alias_dict['column_aliases'].values()
        replace = True
    except KeyError:
        replace = False
    
    df[alias] = df[column_name]
    
    if replace:
        df[alias] = df[alias].replace(column_from, column_to)
        
    return df

def alias_columns(df, column_names, alias_dict):
    for column in column_names:
        try:
            df = alias_column(df, column, alias_dict[column])
        except Exception as e:
            print e
    
    return df

syn = synapseclient.login(silent=True)

con = boto.connect_s3(profile_name='sagestaticbucket')
con.get_bucket('nda-bsmn')
b = con.get_bucket('nda-bsmn')

synapse_data_folder = 'syn7872188'
synapse_data_folder_id = int(synapse_data_folder.replace('syn', ''))
storage_location_id = '9209'
bucket_name = 'nda-bsmn'

# base_path = 'abyzova_1481392262177'
# subject_file_name = 'BSMN_REF_subject.csv'
# samples_file_name = 'BSMN_REF_samples.final.txt'
# manifest_file_name = '.manifest'

synapse_data_folder = 'syn7872188'
synapse_data_folder_id = int(synapse_data_folder.replace('syn', ''))
storage_location_id = '9209'
bucket_name = 'nda-bsmn'

base_path = 'jmkidd_1491406438314'
subject_file_name = 'genomics_subject02_template.csv'
samples_file_name = 'genomics_sample03_template.csv'
btb_file_name = 'nichd_btb02_template.csv'
manifest_file_name = '.manifest'

# Set up aliases and lookup dictionaries
content_type_dict = {'.gz': 'application/x-gzip', '.bam': 'application/octet-stream'}
subject_column_aliases = json.load(file("subject_column_aliases.json"))
sample_column_aliases = json.load(file("sample_column_aliases.json"))

# Read files
subject_key = b.get_key("%s/%s" % (base_path, subject_file_name))
samples_key = b.get_key("%s/%s" % (base_path, samples_file_name))
manifest_key = b.get_key("%s/%s" % (base_path, manifest_file_name))
btb_key = b.get_key("%s/%s" % (base_path, btb_file_name))

subject = pandas.read_csv(StringIO.StringIO(subject_key.read()), delimiter=",", header=1)
samples = pandas.read_csv(StringIO.StringIO(samples_key.read()), delimiter=",", header=1)
btb = pandas.read_csv(StringIO.StringIO(btb_key.read()), delimiter=",", header=1)
manifest = pandas.read_csv(StringIO.StringIO(manifest_key.read()), delimiter="\t", names=['filename', 'md5', 'size'])

content_type_dict = {'.gz': 'application/x-gzip', '.bam': 'application/octet-stream', '.bai': 'application/octet-stream'}

# %% [markdown]
# ### Read and process subject file

# %%
### Process subject file
subject = alias_columns(subject, subject_column_aliases.keys(), subject_column_aliases)

subject = subject[['src_subject_id', 'gender', 'race', 'ethnic_group', 'phenotype', 
                   'subject_sample_id_original', 'sample_description', 'subject_biorepository', 'sex']]

# %%
subject
# Out:
#    src_subject_id gender   race  ethnic_group phenotype  \
# 0            5154      M  White           NaN    normal
#
#    subject_sample_id_original sample_description subject_biorepository   sex
# 0                        5154              brain                  LIBD  male

# %% [markdown]
# ### Read and process sample file

# %%
### Process sample file
samples1 = samples[['src_subject_id', 'experiment_id', 'subjectkey', 'sample_id_original', 'organism', 
                   'sample_amount', 'sample_unit', 'biorepository', 'comments_misc', 'site', 'data_file1', 'data_file1_type']]

samples1 = alias_columns(samples1, sample_column_aliases.keys(), sample_column_aliases)

aliased_cols = list(set(samples1.columns).intersection([x['alias'] for x in sample_column_aliases.values()]))

keep_cols = ['src_subject_id', 'experiment_id', 'subjectkey', 'sample_id_original', 'organism', 
             'sample_amount', 'sample_unit', 'biorepository', 'comments_misc', 'site'] + aliased_cols

samples1 = samples1[keep_cols]

samples2 = samples[['src_subject_id', 'experiment_id', 'subjectkey', 'sample_id_original', 'organism',
                    'sample_amount', 'sample_unit', 'biorepository', 'comments_misc', 'site', 'data_file2', 'data_file2_type']]

samples2 = alias_columns(samples2, sample_column_aliases.keys(), sample_column_aliases)

aliased_cols = list(set(samples2.columns).intersection([x['alias'] for x in sample_column_aliases.values()]))

keep_cols = ['src_subject_id', 'experiment_id', 'subjectkey', 'sample_id_original', 'organism', 
             'sample_amount', 'sample_unit', 'biorepository', 'comments_misc', 'site'] + aliased_cols

samples2 = samples2[keep_cols]

samples3 = pandas.concat([samples1, samples2], ignore_index=True)

# Remove initial slash to match what is in manifest file
samples3.filename = samples3['filename'].apply(lambda value: value[1:] if not pandas.isnull(value) else value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b71bd4150316> in <module>()
# ----> 1 samples['species'] = samples['organism'].replace(['Homo Sapiens'], ['Human'])
#       2
#       3 samples1 = samples[['src_subject_id', 'experiment_id', 'subjectkey', 'sample_id_original', 'organism', 'species',
#       4                    'sample_amount', 'sample_unit', 'biorepository', 'comments_misc', 'site', 'data_file1', 'data_file1_type']]
#       5
#
# /usr/lib64/python2.7/site-packages/pandas/core/generic.pyc in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3074                                                        dest_list=value,
#    3075                                                        inplace=inplace,
# -> 3076                                                        regex=regex)
#    3077
#    3078                 else:  # [NA, ''] -> 0
#
# /usr/lib64/python2.7/site-packages/pandas/core/internals.pyc in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    2884             return _possibly_compare(values, getattr(s, 'asm8', s),
#    2885                                      operator.eq)
# -> 2886         masks = [comp(s) for i, s in enumerate(src_list)]
#    2887
#    2888         result_blocks = []
#
# /usr/lib64/python2.7/site-packages/pandas/core/internals.pyc in comp(s)
#    2883                 return isnull(values)
#    2884             return _possibly_compare(values, getattr(s, 'asm8', s),
# -> 2885                                      operator.eq)
#    2886         masks = [comp(s) for i, s in enumerate(src_list)]
#    2887
#
# /usr/lib64/python2.7/site-packages/pandas/core/internals.pyc in _possibly_compare(a, b, op)
#    4281             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4282
# -> 4283         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4284     return result
#    4285
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'

# %%
# Merge to make metadata

metadata = pandas.merge(samples3, subject, how='left', 
                        left_on='src_subject_id', right_on='src_subject_id')

metadata.index = metadata.filename

metadata.drop('filename', axis=1, inplace=True)

manifest_list = manifest.transpose().to_dict().values()

# %%
# Make links in Synapse

force_remove = False

for (n, x) in enumerate(manifest_list):
    s3FilePath = os.path.basename("%s/%s" % (base_path, x['filename']))
    contentSize = x['size']
    contentMd5 = x['md5']

    # Check if it exists in Synapse
    res = syn.restGET("/entity/md5/%s" % (contentMd5, ))['results']
    
    res = filter(lambda x: x['benefactorId'] == synapse_data_folder_id, res)
    
    if len(res) > 0:
        print "%s already exists in Synapse (count = %s)" % (os.path.split(x['filename'])[1], len(res))

        if force_remove:

            for entity_record in res:
                fhs = syn.restGET("/entity/%(id)s/version/%(versionNumber)s/filehandles" % entity_record)
        
            syn.delete(entity_record['id'], version=entity_record['versionNumber'])
        
            for fh in fhs['list']:
                syn.restDELETE("/fileHandle/%(id)s" % fh, syn.fileHandleEndpoint)
    
            
    else:
        print "Adding %s (%s)" % (contentMd5, x['filename'])
        break

        
    contentType = content_type_dict.get(os.path.splitext(x['filename'])[-1],
                                        'application/octet-stream')
    
    try:
        a = metadata.loc[x['filename']].to_dict()
    except KeyError:
        a = {}
    
    fileHandle = {'concreteType': 'org.sagebionetworks.repo.model.file.S3FileHandle',
                  'fileName'    : s3FileName,
                  'contentSize' : contentSize,
                  'contentType' : contentType,
                  'contentMd5' :  contentMd5,
                  'bucketName' : bucket_name,
                  'key'        : s3FilePath,
                  'storageLocationId' : storage_location_id}

    fileHandleObj = syn.restPOST('/externalFileHandle/s3', 
                                 json.dumps(fileHandle), 
                                 endpoint=syn.fileHandleEndpoint)

    f = synapseclient.File(parentId=synapse_data_folder, 
                           name=s3FileName, 
                           dataFileHandleId = fileHandleObj['id'])
    f.annotations = a

    f = syn.store(f, forceVersion=False)
# Out:
# 0 {'size': 88507688, 'md5': 'c5842fe9a698aa859aaaafa6fff291b6', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A1/A1_S1_L008_R1_001.fastq.gz'}
# 1 {'size': 100329084, 'md5': '3c93da5510d36e2bf2ff180960e715c1', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A1/A1_S1_L008_R2_001.fastq.gz'}
# 2 {'size': 117121052, 'md5': 'f57fb5bcc68218ed007da03046064d9d', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A2/A2_S2_L008_R1_001.fastq.gz'}
# 3 {'size': 132967017, 'md5': 'def37d7e4f28ee31961e6629962f7c8c', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A2/A2_S2_L008_R2_001.fastq.gz'}
# 4 {'size': 98352274, 'md5': '55edf14895f8d7a4fe941b177d80ee62', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A3/A3_S3_L008_R1_001.fastq.gz'}
# 5 {'size': 111755645, 'md5': '21f9653fa73f727058c993dd07dbc47f', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A3/A3_S3_L008_R2_001.fastq.gz'}
# 6 {'size': 222755660, 'md5': 'cfbeeddac76851b202b9e9ff9047e8c8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A4/A4_S4_L008_R1_001.fastq.gz'}
# 7 {'size': 253503877, 'md5': '318748e82aa2cd21b3b52da72a7f9b09', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_A4/A4_S4_L008_R2_001.fastq.gz'}
# 8 {'size': 201714370, 'md5': '1ba06612c663dc88189eae11c97a148c', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_
 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B4/B4_S16_L008_R1_001.fastq.gz'}
# 31 {'size': 878929496, 'md5': '027bfaf6eb5a513673684c9bd21ce4b3', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B4/B4_S16_L008_R2_001.fastq.gz'}
# 32 {'size': 198378237, 'md5': '0732a381899ab295daaf2ea8e4bbf7e4', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B5/B5_S17_L008_R1_001.fastq.gz'}
# 33 {'size': 228239887, 'md5': '172be44f3ea669ac7d43fac68387e39e', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B5/B5_S17_L008_R2_001.fastq.gz'}
# 34 {'size': 226345582, 'md5': '57e0bd1ffd038951b7f215fd906f5b28', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B6/B6_S18_L008_R1_001.fastq.gz'}
# 35 {'size': 261003924, 'md5': 'fdcf8f66d795ff8c18049fe3ed2273e4', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B6/B6_S18_L008_R2_001.fastq.gz'}
# 36 {'size': 139043466, 'md5': '49b4fb7c05ed17beded53f9251435c4e', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B7/B7_S19_L008_R1_001.fastq.gz'}
# 37 {'size': 160452499, 'md5': 'cf671c16ee5d85ba85ee7ecb3597847a', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B7/B7_S19_L008_R2_001.fastq.gz'}
# 38 {'size': 225249453, 'md5': '566eb427bc1110511b9e7f1ba16f50c7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B8/B8_S20_L008_R1_001.fastq.gz'}
# 39 {'size': 259429690, 'md5': 'b1ea1350d6e5cbae2059f0d7cce010f8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B8/B8_S20_L008_R2_001.fastq.gz'}
# 40 {'size': 128772319, 'md5': '4af57ac18cc4d60aae407a96ddad982d', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B9/B9_S21_L008_R1_001.fastq.gz'}
# 41 {'size': 148209602, 'md5': '2c94ae8461490165c7c7bebeeb68a37f', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B9/B9_S21_L008_R2_001.fastq.gz'}
# 42 {'size': 127906490, 'md5': '89d37562fb4c16d4b1cddef265de4d5e', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B10/B10_S22_L008_R1_001.fastq.gz'}
# 43 {'size': 146210553, 'md5': '9bfbffd3aa4a0d5ed3cd40c110868c09', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B10/B10_S22_L008_R2_001.fastq.gz'}
# 44 {'size': 136361732, 'md5': 'fee59c20345f5fccb22f000a59f1ea5e', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B11/B11_S23_L008_R1_001.fastq.gz'}
# 45 {'size': 157022981, 'md5': 'c308e21aae1a3599c1fcca08f9cc9d91', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B11/B11_S23_L008_R2_001.fastq.gz'}
# 46 {'size': 123605015, 'md5': 'eec7ac757f93c6bfbbb6618b2a9ff52c', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B12/B12_S24_L008_R1_001.fastq.gz'}
# 47 {'size': 142156223, 'md5': '1c60f36ef26eb9c4b283841c597e17c5', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_B12/B12_S24_L008_R2_001.fastq.gz'}
# 48 {'size': 309678880, 'md5': '6c69a49efee02cd32a03e4e424cdd83a', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C1/C1_S25_L008_R1_001.fastq.gz'}
# 49 {'size': 353353626, 'md5': 'e606f59e9d9e2e5195d3cbe9c6c1a71b', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C1/C1_S25_L008_R2_001.fastq.gz'}
# 50 {'size': 279008667, 'md5': '45d6c6385b0f6efe2996d5eb821855c8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C2/C2_S26_L008_R1_001.fastq.gz'}
# 51 {'size': 318977839, 'md5': '94f1249a17677a60c5e6656bafb849d8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C2/C2_S26_L008_R2_001.fastq.gz'}
# 52 {'size': 190047940, 'md5': '057621bcf276b30f9f6b26e4dcf17061', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C3/C3_S27_L008_R1_001.fastq.gz'}
# 53 {'size': 217679861, 'md5': '22670ab57f500e52c1d9f436742ce913', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C3/C3_S27_L008_R2_001.fastq.gz'}
# 54 {'size': 320212221, 'md5': '78a28e7923a4d5fa1feb850e4ba92253', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C4/C4_S28_L008_R1_001.fastq.gz'}
# 55 {'size': 368094044, 'md5': '31d5418d9a9695611c035f26944195ef', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C4/C4_S28_L008_R2_001.fastq.gz'}
# 56 {'size': 260419310, 'md5': '76a7f7987f9320a7478c77de896bc119', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C5/C5_S29_L008_R1_001.fastq.gz'}
# 57 {'size': 297821719, 'md5': '04fdc2a5cbdfce6b3c917defef978ee7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C5/C5_S29_L008_R2_001.fastq.gz'}
# 58 {'size': 201365082, 'md5': 'eb32fbf49a17957df05906d13af6fbdf', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C6/C6_S30_L008_R1_001.fastq.gz'}
# 59 {'size': 228259157, 'md5': '8175c1e792e918ad9b21f414a2dbd60f', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C6/C6_S30_L008_R2_001.fastq.gz'}
# 60 {'size': 188177119, 'md5': '08bd032fa4c8f49e0fb28cae858ce1e7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C7/C7_S31_L008_R1_001.fastq.gz'}
# 61 {'size': 215216150, 'md5': 'b3f605b87441f0df7077c4cb7a6b4f4c', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C7/C7_S31_L008_R2_001.fastq.gz'}
# 62 {'size': 386305743, 'md5': '17f81b793376fbcd3cabf1ec1348a77f', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C8/C8_S32_L008_R1_001.fastq.gz'}
# 63 {'size': 441770101, 'md5': 'd0b4e4f373412b8a84eb790b33c64abd', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C8/C8_S32_L008_R2_001.fastq.gz'}
# 64 {'size': 257522314, 'md5': '7560101a18b69b144d934c88e7b0a710', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C9/C9_S33_L008_R1_001.fastq.gz'}
# 65 {'size': 295539442, 'md5': 'f2da9236cc300ad3c0a98c3050a04b18', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C9/C9_S33_L008_R2_001.fastq.gz'}
# 66 {'size': 260291361, 'md5': 'af6d197604d38cf6dca5bddef4a196bd', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C10/C10_S34_L008_R1_001.fastq.gz'}
# 67 {'size': 299195996, 'md5': '6b3dc4614ec41346a04e757343b319e6', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C10/C10_S34_L008_R2_001.fastq.gz'}
# 68 {'size': 122087875, 'md5': 'cf5dd6223493695b9f7505145b06f750', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C11/C11_S35_L008_R1_001.fastq.gz'}
# 69 {'size': 140379552, 'md5': '81c07d90187a11827b540fa41bf31770', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C11/C11_S35_L008_R2_001.fastq.gz'}
# 70 {'size': 402670692, 'md5': '7e68b68062c040b1d5f7b4231e283580', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C12/C12_S36_L008_R1_001.fastq.gz'}
# 71 {'size': 463857878, 'md5': '89d33b6c32270c36a78156f639557756', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_C12/C12_S36_L008_R2_001.fastq.gz'}
# 72 {'size': 215579915, 'md5': '07f6eba3081f610dffdc2f80e8279495', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_D1/D1_S37_L008_R1_001.fastq.gz'}
# 73 {'size': 246720067, 'md5': '7edcf04c6ee27a341f1a89a0fb49edff', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_
 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E_D12/D12_S48_L008_R2_001.fastq.gz'}
# 96 {'size': 264225999, 'md5': 'fe6cb3792a763226046ecfb634fedf1a', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E1/E1_S49_L008_R1_001.fastq.gz'}
# 97 {'size': 302782834, 'md5': '0d5053e1cfca11ccb6692cd7344d73f5', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E1/E1_S49_L008_R2_001.fastq.gz'}
# 98 {'size': 286148456, 'md5': '3ef26f8f95f832fcd6605bde59d92e17', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E2/E2_S50_L008_R1_001.fastq.gz'}
# 99 {'size': 328867296, 'md5': '56f79d662cedcfcb2530a96d47177a24', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E2/E2_S50_L008_R2_001.fastq.gz'}
# 100 {'size': 343569375, 'md5': '7287eeb8d9ec83f53b8f71206ebd3864', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E3/E3_S51_L008_R1_001.fastq.gz'}
# 101 {'size': 394522066, 'md5': '33e72493305a1039e4d5f2d71b97505b', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E3/E3_S51_L008_R2_001.fastq.gz'}
# 102 {'size': 587358214, 'md5': '3aebc8bbb74fbf3c876936ab8564528d', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E4/E4_S52_L008_R1_001.fastq.gz'}
# 103 {'size': 676189804, 'md5': 'a82991cb051f8b61fd5e2605cd6468b8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E4/E4_S52_L008_R2_001.fastq.gz'}
# 104 {'size': 629604062, 'md5': '55bf8699f096c5fb256e2c932ef3e6a8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E5/E5_S53_L008_R1_001.fastq.gz'}
# 105 {'size': 723317213, 'md5': 'c35bab7034a31bd6adf942db00102af8', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E5/E5_S53_L008_R2_001.fastq.gz'}
# 106 {'size': 268054906, 'md5': '2f52a81441145164395962b575c73eb7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E6/E6_S54_L008_R1_001.fastq.gz'}
# 107 {'size': 304883891, 'md5': '0fed7bc583eb2e42281b9ad0bc9ea5d0', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E6/E6_S54_L008_R2_001.fastq.gz'}
# 108 {'size': 451477300, 'md5': 'b560eb77c93fe4f71966f5fcb2c408cb', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E7/E7_S55_L008_R1_001.fastq.gz'}
# 109 {'size': 519450015, 'md5': '82c075070cc6bb6b96c4e4b0509d9fd7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E7/E7_S55_L008_R2_001.fastq.gz'}
# 110 {'size': 436335270, 'md5': 'a427c46e8551724e5fccc1b91e6e6a14', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E8/E8_S56_L008_R1_001.fastq.gz'}
# 111 {'size': 501077569, 'md5': '6204eff4819eb7bd4ea19206b123f1f7', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E8/E8_S56_L008_R2_001.fastq.gz'}
# 112 {'size': 481114727, 'md5': 'ce84da1a84aacc55cc50a98db17e9823', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E9/E9_S57_L008_R1_001.fastq.gz'}
# 113 {'size': 549375212, 'md5': '33070aafb06ebefd7d37d3a98d51cdd1', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E9/E9_S57_L008_R2_001.fastq.gz'}
# 114 {'size': 369454299, 'md5': '875ddb769163e0de4d5f8f55d39f2c78', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E10/E10_S58_L008_R1_001.fastq.gz'}
# 115 {'size': 422382614, 'md5': '7ea326099c5eed4280f9b73b2fff707e', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E10/E10_S58_L008_R2_001.fastq.gz'}
# 116 {'size': 298265378, 'md5': 'a2c803cb0d63efb5c7d9c512de5df5c9', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E11/E11_S59_L008_R1_001.fastq.gz'}
# 117 {'size': 341469844, 'md5': 'e872e2f7f49de47d28da8570e897545b', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E11/E11_S59_L008_R2_001.fastq.gz'}
# 118 {'size': 434308952, 'md5': 'e4b4dde406f26527a99a8b3e5415cfce', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E12/E12_S60_L008_R1_001.fastq.gz'}
# 119 {'size': 498874014, 'md5': 'd3e094e30382338efb26ba0427d3e113', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_E12/E12_S60_L008_R2_001.fastq.gz'}
# 120 {'size': 319683813, 'md5': '8ef337bea994d0f10108356c793622dd', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F1/F1_S61_L008_R1_001.fastq.gz'}
# 121 {'size': 366097567, 'md5': 'fac8e6400a88c43890ac2cfdfca6ebbd', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F1/F1_S61_L008_R2_001.fastq.gz'}
# 122 {'size': 192772559, 'md5': '3c17b56ff76f81a448a4f78caf05f4e4', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F2/F2_S62_L008_R1_001.fastq.gz'}
# 123 {'size': 219260519, 'md5': '25cb843676c2763b2fdbfcc78dcdb398', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F2/F2_S62_L008_R2_001.fastq.gz'}
# 124 {'size': 536501149, 'md5': '54d40d52f742cf92b06d916f6aa0ce19', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F3/F3_S63_L008_R1_001.fastq.gz'}
# 125 {'size': 614323258, 'md5': '34c027854aa8ddf2d3fd5863993ebfb1', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F3/F3_S63_L008_R2_001.fastq.gz'}
# 126 {'size': 330621274, 'md5': '8d4ceda58d85cf746a59d56abca86f33', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F4/F4_S64_L008_R1_001.fastq.gz'}
# 127 {'size': 378721888, 'md5': 'cf0009365be349751ebc55d64106bbb2', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F4/F4_S64_L008_R2_001.fastq.gz'}
# 128 {'size': 191566069, 'md5': '59a31a59944d66d66a72273a0d02a704', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F5/F5_S65_L008_R1_001.fastq.gz'}
# 129 {'size': 218076411, 'md5': '80ba07b7d12f8a0b7c16f1a07c0dafd4', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F5/F5_S65_L008_R2_001.fastq.gz'}
# 130 {'size': 206343891, 'md5': 'ffc972722490a7679176bdb321c07186', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F6/F6_S66_L008_R1_001.fastq.gz'}
# 131 {'size': 235293346, 'md5': '9127eee87ce1710d499a485310c791e2', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F6/F6_S66_L008_R2_001.fastq.gz'}
# 132 {'size': 222689567, 'md5': '672dfadf59ebd27c4ce805a9160c8415', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F7/F7_S67_L008_R1_001.fastq.gz'}
# 133 {'size': 253859108, 'md5': 'aa742f87a794d0f29cad6cdde3ba32ad', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/Project_Lt76/Sample_F7/F7_S67_L008_R2_001.fastq.gz'}
# 134 {'size': 96855549921, 'md5': '58c620a48c3167f74b9284cece02467a', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/1608UNHX-0001/Neun-Minus/Neun-Minus_sorted.bam'}
# 135 {'size': 81579902466, 'md5': 'fe0ef6b0e272bfd4eaf4526ed730a1b5', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/1608UNHX-0001/Neun-Plus/Neun-Plus_sorted.bam'}
# 136 {'size': 536384486585, 'md5': '3e798cece752cca16bc81e7a53387fda', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/1608UNHX-0002/bulk/bulk_sorted.bam'}
# 137 {'size': 506077901880, 'md5': '1a19514e742999046be47892b883c24a', 'filename': 'Volumes/Promise Pegasus/data/s203958.TS_mosaicism/1608UNHX-0002/fibroblasts/fibroblasts_sorted.bam'}
